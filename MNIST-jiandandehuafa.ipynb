# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
#载入数据
mnist = input_data.read_data_sets("MNIST_data",one_hot=True)
#每个批次的大小
batch_size = 100
#计算一共多少批次
n_batch = mnist.train.num_examples // batch_size

#定义两个placeholder
x = tf.placeholder(tf.float32,[None,784])
y = tf.placeholder(tf.float32,[None,10])

#c创建一个神经网络

W= tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))
prediction = tf.nn.softmax(tf.matmul(x,W)+b)

#二次代价函数
# loss = tf.reduce_mean(tf.square(y - prediction))
#似然对数代价函数
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels =y,logits= prediction))

#使用梯度下降法
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

#初始化变量
init = tf.global_variables_initializer()

#结果存放在一个布尔列表中
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))
#求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(210):
        for batch in range(n_batch):
            batch_xs,batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys})
        
        acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print("Iter" +str(epoch) +',Testing Accuracy' +str(acc))
# Out:
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# Iter0,Testing Accuracy0.8249
# Iter1,Testing Accuracy0.8942
# Iter2,Testing Accuracy0.9012
# Iter3,Testing Accuracy0.9049
# Iter4,Testing Accuracy0.9089
# Iter5,Testing Accuracy0.9095
# Iter6,Testing Accuracy0.9117
# Iter7,Testing Accuracy0.9126
# Iter8,Testing Accuracy0.9157
# Iter9,Testing Accuracy0.9159
# Iter10,Testing Accuracy0.9161
# Iter11,Testing Accuracy0.9177
# Iter12,Testing Accuracy0.9189
# Iter13,Testing Accuracy0.92
# Iter14,Testing Accuracy0.9202
# Iter15,Testing Accuracy0.9199
# Iter16,Testing Accuracy0.9209
# Iter17,Testing Accuracy0.9211
# Iter18,Testing Accuracy0.9217
# Iter19,Testing Accuracy0.9216
# Iter20,Testing Accuracy0.9213
# Iter21,Testing Accuracy0.9217
# Iter22,Testing Accuracy0.9214
# Iter23,Testing Accuracy0.9232
# Iter24,Testing Accuracy0.9232
# Iter25,Testing Accuracy0.9234
# Iter26,Testing Accuracy0.9224
# Iter27,Testing Accuracy0.9236
# Iter28,Testing Accuracy0.9228
# Iter29,Testing Accuracy0.9242
# Iter30,Testing Accuracy0.9236
# Iter31,Testing Accuracy0.924
# Iter32,Testing Accuracy0.9241
# Iter33,Testing Accuracy0.924
# Iter34,Testing Accuracy0.9242
# Iter35,Testing Accuracy0.9244
# Iter36,Testing Accuracy0.9257
# Iter37,Testing Accuracy0.9257
# Iter38,Testing Accuracy0.9252
# Iter39,Testing Accuracy0.9254
# Iter40,Testing Accuracy0.9251
# Iter41,Testing Accuracy0.9261
# Iter42,Testing Accuracy0.9262
# Iter43,Testing Accuracy0.9253
# Iter44,Testing Accuracy0.9258
# Iter45,Testing Accuracy0.9262
# Iter46,Testing Accuracy0.927
# Iter47,Testing Accuracy0.9271
# Iter48,Testing Accuracy0.9265
# Iter49,Testing Accuracy0.9266
# Iter50,Testing Accuracy0.9271
# Iter51,Testing Accuracy0.9269
# Iter52,Testing Accuracy0.9278
# Iter53,Testing Accuracy0.9269
# Iter54,Testing Accuracy0.927
# Iter55,Testing Accuracy0.9278
# Iter56,Testing Accuracy0.9264
# Iter57,Testing Accuracy0.9274
# Iter58,Testing Accuracy0.9284
# Iter59,Testing Accuracy0.9282
# Iter60,Testing Accuracy0.9279
# Iter61,Testing Accuracy0.9285
# Iter62,Testing Accuracy0.9282
# Iter63,Testing Accuracy0.9274
# Iter64,Testing Accuracy0.9271
# Iter65,Testing Accuracy0.9287
# Iter66,Testing Accuracy0.9277
# Iter67,Testing Accuracy0.9281
# Iter68,Testing Accuracy0.9287
# Iter69,Testing Accuracy0.9285
# Iter70,Testing Accuracy0.9282
# Iter71,Testing Accuracy0.9286
# Iter72,Testing Accuracy0.9287
# Iter73,Testing Accuracy0.9285
# Iter74,Testing Accuracy0.9287
# Iter75,Testing Accuracy0.9281
# Iter76,Testing Accuracy0.9287
# Iter77,Testing Accuracy0.928
# Iter78,Testing Accuracy0.9277
# Iter79,Testing Accuracy0.928
# Iter80,Testing Accuracy0.9276
# Iter81,Testing Accuracy0.927
# Iter82,Testing Accuracy0.9281
# Iter83,Testing Accuracy0.9287
# Iter84,Testing Accuracy0.9286
# Iter85,Testing Accuracy0.928
# Iter86,Testing Accuracy0.9288
# Iter87,Testing Accuracy0.9277
# Iter88,Testing Accuracy0.9285
# Iter89,Testing Accuracy0.9284
# Iter90,Testing Accuracy0.9283
# Iter91,Testing Accuracy0.9284
# Iter92,Testing Accuracy0.9282
# Iter93,Testing Accuracy0.928
# Iter94,Testing Accuracy0.9284
# Iter95,Testing Accuracy0.9292
# Iter96,Testing Accuracy0.9291
# Iter97,Testing Accuracy0.9286
# Iter98,Testing Accuracy0.929
# Iter99,Testing Accuracy0.9293
# Iter100,Testing Accuracy0.9292
# Iter101,Testing Accuracy0.9284
# Iter102,Testing Accuracy0.9288
# Iter103,Testing Accuracy0.9287
# Iter104,Testing Accuracy0.9285
# Iter105,Testing Accuracy0.9287
# Iter106,Testing Accuracy0.9289
# Iter107,Testing Accuracy0.9289
# Iter108,Testing Accuracy0.9287
# Iter109,Testing Accuracy0.9279
# Iter110,Testing Accuracy0.9292
# Iter111,Testing Accuracy0.9288
# Iter112,Testing Accuracy0.9283
# Iter113,Testing Accuracy0.9283
# Iter114,Testing Accuracy0.9286
# Iter115,Testing Accuracy0.9288
# Iter116,Testing Accuracy0.9283
# Iter117,Testing Accuracy0.9286
# Iter118,Testing Accuracy0.9285
# Iter119,Testing Accuracy0.9283
# Iter120,Testing Accuracy0.9278
# Iter121,Testing Accuracy0.9289
# Iter122,Testing Accuracy0.9286
# Iter123,Testing Accuracy0.9287
# Iter124,Testing Accuracy0.9289
# Iter125,Testing Accuracy0.9284
# Iter126,Testing Accuracy0.9282
# Iter127,Testing Accuracy0.9284
# Iter128,Testing Accuracy0.9282
# Iter129,Testing Accuracy0.9283
# Iter130,Testing Accuracy0.9278
# Iter131,Testing Accuracy0.9284
# Iter132,Testing Accuracy0.9287
# Iter133,Testing Accuracy0.9281
# Iter134,Testing Accuracy0.9282
# Iter135,Testing Accuracy0.9282
# Iter136,Testing Accuracy0.9284
# Iter137,Testing Accuracy0.9292
# Iter138,Testing Accuracy0.9288
# Iter139,Testing Accuracy0.9287
# Iter140,Testing Accuracy0.9287
# Iter141,Testing Accuracy0.9284
# Iter142,Testing Accuracy0.9286
# Iter143,Testing Accuracy0.9288
# Iter144,Testing Accuracy0.9285
# Iter145,Testing Accuracy0.929
# Iter146,Testing Accuracy0.9289
# Iter147,Testing Accuracy0.9284
# Iter148,Testing Accuracy0.929
# Iter149,Testing Accuracy0.9285
# Iter150,Testing Accuracy0.9285
# Iter151,Testing Accuracy0.9287
# Iter152,Testing Accuracy0.9288
# Iter153,Testing Accuracy0.9292
# Iter154,Testing Accuracy0.9288
# Iter155,Testing Accuracy0.9291
# Iter156,Testing Accuracy0.9288
# Iter157,Testing Accuracy0.9289
# Iter158,Testing Accuracy0.9291
# Iter159,Testing Accuracy0.9296
# Iter160,Testing Accuracy0.9292
# Iter161,Testing Accuracy0.9286
# Iter162,Testing Accuracy0.929
# Iter163,Testing Accuracy0.9294
# Iter164,Testing Accuracy0.9289
# Iter165,Testing Accuracy0.9289
# Iter166,Testing Accuracy0.9286
# Iter167,Testing Accuracy0.9285
# Iter168,Testing Accuracy0.9293
# Iter169,Testing Accuracy0.929
# Iter170,Testing Accuracy0.929
# Iter171,Testing Accuracy0.9293
# Iter172,Testing Accuracy0.9298
# Iter173,Testing Accuracy0.9291
# Iter174,Testing Accuracy0.9292
# Iter175,Testing Accuracy0.9294
# Iter176,Testing Accuracy0.9295
# Iter177,Testing Accuracy0.9293
# Iter178,Testing Accuracy0.9294
# Iter179,Testing Accuracy0.9293
# Iter180,Testing Accuracy0.9294
# Iter181,Testing Accuracy0.9293
# Iter182,Testing Accuracy0.9295
# Iter183,Testing Accuracy0.9299
# Iter184,Testing Accuracy0.9292
# Iter185,Testing Accuracy0.9297
# Iter186,Testing Accuracy0.9297
# Iter187,Testing Accuracy0.9295
# Iter188,Testing Accuracy0.9292
# Iter189,Testing Accuracy0.9299
# Iter190,Testing Accuracy0.9293
# Iter191,Testing Accuracy0.9293
# Iter192,Testing Accuracy0.9292
# Iter193,Testing Accuracy0.9295
# Iter194,Testing Accuracy0.9298
# Iter195,Testing Accuracy0.9293
# Iter196,Testing Accuracy0.9294
# Iter197,Testing Accuracy0.9298
# Iter198,Testing Accuracy0.9296
# Iter199,Testing Accuracy0.9297
# Iter200,Testing Accuracy0.9298
# Iter201,Testing Accuracy0.93
# Iter202,Testing Accuracy0.9299
# Iter203,Testing Accuracy0.9298
# Iter204,Testing Accuracy0.9296
# Iter205,Testing Accuracy0.9297
# Iter206,Testing Accuracy0.93
# Iter207,Testing Accuracy0.9299
# Iter208,Testing Accuracy0.93
# Iter209,Testing Accuracy0.9294
