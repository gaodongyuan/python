# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
#载入数据
mnist = input_data.read_data_sets("MNIST_data",one_hot=True)
#每个批次的大小
batch_size = 100
#计算一共多少批次
n_batch = mnist.train.num_examples // batch_size

#定义两个placeholder
x = tf.placeholder(tf.float32,[None,784])
y = tf.placeholder(tf.float32,[None,10])
keep_prob = tf.placeholder(tf.float32)
lr = tf.Variable(0.001,dtype=tf.float32)
#c创建一个神经网络


W1 = tf.Variable(tf.truncated_normal([784,500],stddev=0.1))
b1 = tf.Variable(tf.zeros([500])+0.1)
L1 = tf.nn.tanh(tf.matmul(x,W1) + b1)
L1_drop = tf.nn.dropout(L1,keep_prob)  # keep_prob决定多少神经元工作

W2 = tf.Variable(tf.truncated_normal([500,300],stddev=0.1))
b2 = tf.Variable(tf.zeros([300]) +0.1)
L2 = tf.nn.tanh(tf.matmul(L1_drop,W2) + b2)
L2_drop = tf.nn.dropout(L2,keep_prob)  # keep_prob决定多少神经元工作

W3 = tf.Variable(tf.truncated_normal([300,10],stddev=0.1))
b3 = tf.Variable(tf.zeros([10])+0.1)
prediction = tf.nn.softmax(tf.matmul(L2_drop,W3)+b3)

#二次代价函数
# loss = tf.reduce_mean(tf.square(y - prediction))
#交叉商代价函数
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels =y,logits= prediction))

#使用梯度下降法
train_step = tf.train.AdamOptimizer(lr).minimize(loss)

#初始化变量
init = tf.global_variables_initializer()

#结果存放在一个布尔列表中
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))
#求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(51):
        sess.run(tf.assign(lr,0.001*(0.98**epoch)))
        for batch in range(n_batch):
            batch_xs,batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys,keep_prob:1.0})
        lenring_rate = sess.run(lr)
        test_acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels,keep_prob:1.0})
#         train_acc = sess.run(accuracy,feed_dict={x:mnist.train.images,y:mnist.train.labels,keep_prob:1.0})
        print("Iter" +str(epoch) +',Testing Accuracy' +str(test_acc)+',lenring_rate' +str(lenring_rate))
# Out:
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# Iter0,Testing Accuracy0.946,lenring_rate0.001
# Iter1,Testing Accuracy0.9602,lenring_rate0.00098
# Iter2,Testing Accuracy0.9667,lenring_rate0.0009604
# Iter3,Testing Accuracy0.9716,lenring_rate0.000941192
# Iter4,Testing Accuracy0.9707,lenring_rate0.00092236814
# Iter5,Testing Accuracy0.9733,lenring_rate0.0009039208
# Iter6,Testing Accuracy0.9755,lenring_rate0.00088584237
# Iter7,Testing Accuracy0.9746,lenring_rate0.0008681255
# Iter8,Testing Accuracy0.9767,lenring_rate0.000850763
# Iter9,Testing Accuracy0.9762,lenring_rate0.00083374773
# Iter10,Testing Accuracy0.977,lenring_rate0.0008170728
# Iter11,Testing Accuracy0.9788,lenring_rate0.00080073136
# Iter12,Testing Accuracy0.9796,lenring_rate0.00078471674
# Iter13,Testing Accuracy0.979,lenring_rate0.0007690224
# Iter14,Testing Accuracy0.9771,lenring_rate0.00075364194
# Iter15,Testing Accuracy0.978,lenring_rate0.0007385691
# Iter16,Testing Accuracy0.9761,lenring_rate0.0007237977
# Iter17,Testing Accuracy0.9793,lenring_rate0.00070932176
# Iter18,Testing Accuracy0.9801,lenring_rate0.0006951353
# Iter19,Testing Accuracy0.9796,lenring_rate0.0006812326
# Iter20,Testing Accuracy0.9782,lenring_rate0.000667608
# Iter21,Testing Accuracy0.9789,lenring_rate0.0006542558
# Iter22,Testing Accuracy0.9809,lenring_rate0.0006411707
# Iter23,Testing Accuracy0.9806,lenring_rate0.0006283473
# Iter24,Testing Accuracy0.9775,lenring_rate0.00061578036
# Iter25,Testing Accuracy0.9817,lenring_rate0.0006034647
# Iter26,Testing Accuracy0.9811,lenring_rate0.0005913954
# Iter27,Testing Accuracy0.9786,lenring_rate0.0005795675
# Iter28,Testing Accuracy0.9789,lenring_rate0.00056797615
# Iter29,Testing Accuracy0.9785,lenring_rate0.00055661664
# Iter30,Testing Accuracy0.9784,lenring_rate0.0005454843
# Iter31,Testing Accuracy0.9806,lenring_rate0.0005345746
# Iter32,Testing Accuracy0.9797,lenring_rate0.00052388315
# Iter33,Testing Accuracy0.98,lenring_rate0.0005134055
# Iter34,Testing Accuracy0.9812,lenring_rate0.00050313736
# Iter35,Testing Accuracy0.982,lenring_rate0.0004930746
# Iter36,Testing Accuracy0.9823,lenring_rate0.00048321314
# Iter37,Testing Accuracy0.982,lenring_rate0.00047354886
# Iter38,Testing Accuracy0.9788,lenring_rate0.0004640779
# Iter39,Testing Accuracy0.9798,lenring_rate0.00045479633
# Iter40,Testing Accuracy0.9813,lenring_rate0.0004457004
# Iter41,Testing Accuracy0.9815,lenring_rate0.0004367864
# Iter42,Testing Accuracy0.9819,lenring_rate0.00042805067
# Iter43,Testing Accuracy0.9822,lenring_rate0.00041948966
# Iter44,Testing Accuracy0.98,lenring_rate0.00041109987
# Iter45,Testing Accuracy0.9809,lenring_rate0.00040287786
# Iter46,Testing Accuracy0.9826,lenring_rate0.0003948203
# Iter47,Testing Accuracy0.9821,lenring_rate0.0003869239
# Iter48,Testing Accuracy0.9823,lenring_rate0.00037918543
# Iter49,Testing Accuracy0.9826,lenring_rate0.00037160172
# Iter50,Testing Accuracy0.9809,lenring_rate0.00036416968
